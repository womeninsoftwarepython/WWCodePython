# %% [markdown]
# <a href="https://colab.research.google.com/github/cosmeow/WWCodePython/blob/master/Read_an_image_with_OpenCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
#get image from path
# use wget to retrieve an image from the web. Image is not stored permanently
# !wget "https://static-cse.canva.com/blob/130199/17.1dfc8996.png"
# Out:
# --2021-10-17 01:41:34--  https://static-cse.canva.com/blob/130199/17.1dfc8996.png
# Resolving static-cse.canva.com (static-cse.canva.com)... 104.17.115.17, 104.17.114.17, 2606:4700::6811:7211, ...
# Connecting to static-cse.canva.com (static-cse.canva.com)|104.17.115.17|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 765834 (748K) [image/png]
# Saving to: ‘17.1dfc8996.png’
#
# 17.1dfc8996.png     100%[===================>] 747.88K  --.-KB/s    in 0.05s
#
# 2021-10-17 01:41:34 (14.4 MB/s) - ‘17.1dfc8996.png’ saved [765834/765834]

# %%
# READ AN IMAGE FROM A PATH
#
# To find the image file name, click on the folder icon in the left sidebar
# You will see the file that was downloaded with the !wget command
#   -- Right click on the file and select copy path
#   -- Paste the path between the double quotes

path = "/content/17.1dfc8996.png"
image = cv2.imread(path)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=2160x2160 at 0x7FDF9FA45250>
